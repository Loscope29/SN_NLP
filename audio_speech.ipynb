# %%
import whisper
print("Loading Whisper model...")
model = whisper.load_model("base")
# Out:
# Loading Whisper model...

# %%
print("Transcribing audio...")
import os 
file_path = os.path.join(os.getcwd(), "archive/one_minute_speech.wav")
result = model.transcribe(file_path)
# Out:
# Transcribing audio...
# c:\Users\DELL\Desktop\Master ISJ Data Science\Master 2\NLP\SN NLP\SN_NLP\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
print("Transcribing complete:")
from IPython.display import display, Markdown
display(Markdown(f"```\n{result['text']}\n```"))
# Out:
# Transcribing complete:
# ```
#  Hello and welcome to this short one minute speech. In today's fast-paced world, technology continues to transform the way we live, work, and communicate from artificial intelligence and machine learning to smart devices and cloud computing. The possibilities are endless. We rely on these innovations not just for convenience but for real impact. Improving education, healthcare, and even the environment as we move forward, it's important to stay curious, adaptable, and responsible in how we use technology. Let's continue to build a future that is inclusive, sustainable, and full of opportunity for all. Thank you for listening.
# ```

# %%
language = result['language']
print(f"Detected language: {language}")
# Out:
# Detected language: en

# %%
text = model.transcribe("London has a diverse.wav")
display(Markdown(f"```\n{text['text']}\n```"))
# Out:
# c:\Users\DELL\Desktop\Master ISJ Data Science\Master 2\NLP\SN NLP\SN_NLP\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ```
#  London has a diverse range of people and cultures, and more than 300 languages are spoken in the region.
# ```
